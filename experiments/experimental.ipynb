# %%
import pandas as pd

# %%
df1 = pd.read_csv('D:\All_data_science_project\DASH\IPL\Data\deliveries.csv')

# %%
df1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 243812   1370353       2    Chennai Super Kings               Gujarat Titans
# 243813   1370353       2    Chennai Super Kings               Gujarat Titans
# 243814   1370353       2    Chennai Super Kings               Gujarat Titans
# 243815   1370353       2    Chennai Super Kings               Gujarat Titans
# 243816   1370353       2    Chennai Super Kings               Gujarat Titans
#
# ...

# %%
df2 = pd.read_csv('D:\All_data_science_project\DASH\IPL\Data\matches.csv')

# %%
df2
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League       DJ Hussey
# ...       ...      ...         ...         ...          ...             ...
# 1019  1359544     2023   Bengaluru  2023-05-21       League    Shubman Gill
# 1020  1370350     2023     Chennai  2023-05-23  Qualifier 1      RD Gaikwad
# 1021  1370351     2023     Chennai  2023-05-24   Eliminator   Akash Madhwal
# 1022  1370352     2023   Ahmedabad  2023-05-26  Qualifier 2    Shubman Gill
# 1023  1370353     2023   Ahmedabad  2023-05-29        Final       DP Conway
#
# ...

# %%
# get the column names of the dataframe

df1.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
def see_col(x):
 return df1[x]
see_col('batsman_runs')
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 243812    1
# 243813    1
# 243814    1
# 243815    6
# 243816    4
# Name: batsman_runs, Length: 243817, dtype: int64

# %%
df1['match_id'].nunique()
# Out:
# 1024

# %%
df1['batter'].unique()
# Out:
# array(['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey',
#        'Mohammad Hafeez', 'R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis',
#        'CL White', 'MV Boucher', 'B Akhil', 'AA Noffke', 'P Kumar',
#        'Z Khan', 'SB Joshi', 'PA Patel', 'ML Hayden', 'MEK Hussey',
#        'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'K Goel',
#        'JR Hopes', 'KC Sangakkara', 'Yuvraj Singh', 'SM Katich',
#        'IK Pathan', 'T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif',
#        'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne',
#        'SK Trivedi', 'G Gambhir', 'V Sehwag', 'S Dhawan', 'L Ronchi',
#        'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah',
#        'AM Nayar', 'SM Pollock', 'Harbhajan Singh', 'S Chanderpaul',
#        'LRPL Taylor', 'AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxman',
#        'A Symonds', 'RG Sharma', 'SB Styris', 'AS Yadav', 'SB Bangar',
#        'WPUJC Vaas', 'RP Singh', 'WP Saha', 'LR Shukla',
# ...

# %%
df1[(df1['match_id']==335982) & (df1['batter']=='SC Ganguly')]['batsman_runs'].sum()
# Out:
# 10

# %%
df1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 243812   1370353       2    Chennai Super Kings               Gujarat Titans
# 243813   1370353       2    Chennai Super Kings               Gujarat Titans
# 243814   1370353       2    Chennai Super Kings               Gujarat Titans
# 243815   1370353       2    Chennai Super Kings               Gujarat Titans
# 243816   1370353       2    Chennai Super Kings               Gujarat Titans
#
# ...

# %%
#df1[df1['match_id']==335982]['batter'].unique()
def show_run(matchid,batsmanname):
 x = df1[df1['match_id']==matchid][['batter','batsman_runs','over','ball']]
 x = x[x['batter']==batsmanname]['batsman_runs'].sum()
 return x 

[show_run(335982,batsmanname) for batsmanname in df1[df1['match_id']==335982]['batter'].unique()]
# Out:
# [10, 158, 20, 12, 5, 2, 6, 1, 8, 6, 7, 0, 9, 18, 3, 3]

# %%
import pandas as pd

# Assuming df1 is your DataFrame containing the data
def show_run(matchid, batsmanname):
    x = df1[df1['match_id'] == matchid][['batter', 'batsman_runs', 'over', 'ball']]
    x = x[x['batter'] == batsmanname]['batsman_runs'].sum()
    return x

# Get unique batsman names for match_id 335982
unique_batsmen = df1[df1['match_id'] == 335982]['batter'].unique()

# Create an empty list to store tuples of batsman names and their runs
batsman_runs = []

# Iterate over unique batsmen and calculate total runs for each
for batsmanname in unique_batsmen:
    runs = show_run(335982, batsmanname)
    batsman_runs.append((batsmanname, runs))

# Convert the list of tuples into a DataFrame
result_df = pd.DataFrame(batsman_runs, columns=['batsman', 'runs'])

print(result_df)
# Out:
#             batsman  runs
# 0        SC Ganguly    10
# 1       BB McCullum   158
# 2        RT Ponting    20
# 3         DJ Hussey    12
# 4   Mohammad Hafeez     5
# 5          R Dravid     2
# 6          W Jaffer     6
# 7           V Kohli     1
# 8         JH Kallis     8
# 9          CL White     6
# 10       MV Boucher     7
# 11          B Akhil     0
# 12        AA Noffke     9
# 13          P Kumar    18
# 14           Z Khan     3
# 15         SB Joshi     3

# %%
df1['match_id'].unique()
# Out:
# array([ 335982,  335983,  335984, ..., 1370351, 1370352, 1370353],
#       dtype=int64)

# %%
import pandas as pd

# Assuming df1 is your DataFrame containing the data
def show_run(df, matchid, batsmanname):
    x = df[df['match_id'] == matchid][['batter', 'batsman_runs', 'over', 'ball']]
    x = x[x['batter'] == batsmanname]['batsman_runs'].sum()
    return x

# List of match IDs
match_ids = df1['match_id'].unique() # Add more match IDs as needed

# Create an empty list to store tuples of batsman names and their runs
all_batsman_runs = []

# Iterate over each match ID
for match_id in match_ids:
    # Get unique batsman names for the current match ID
    unique_batsmen = df1[df1['match_id'] == match_id]['batter'].unique()
    
    # Iterate over unique batsmen for the current match
    for batsmanname in unique_batsmen:
        runs = show_run(df1, match_id, batsmanname)
        all_batsman_runs.append((match_id, batsmanname, runs))

# Convert the list of tuples into a DataFrame
batsman_name_and_runs = pd.DataFrame(all_batsman_runs, columns=['match_id', 'batsman', 'runs'])

print(batsman_name_and_runs)
# Out:
#        match_id          batsman  runs
# 0        335982       SC Ganguly    10
# 1        335982      BB McCullum   158
# 2        335982       RT Ponting    20
# 3        335982        DJ Hussey    12
# 4        335982  Mohammad Hafeez     5
# ...         ...              ...   ...
# 15395   1370353           S Dube    32
# 15396   1370353        AM Rahane    27
# 15397   1370353        AT Rayudu    19
# 15398   1370353         MS Dhoni     0
# 15399   1370353        RA Jadeja    15
#
# [15400 rows x 3 columns]

# %%
batsman_name_and_runs.groupby(by='batsman')['runs'].sum().reset_index().sort_values(by='runs',ascending=False).head(10)
# Out:
#             batsman  runs
# 597         V Kohli  7273
# 488        S Dhawan  6617
# 138       DA Warner  6399
# 455       RG Sharma  6213
# 519        SK Raina  5536
# 27   AB de Villiers  5181
# 357        MS Dhoni  5082
# 116        CH Gayle  4997
# 477      RV Uthappa  4954
# 269      KD Karthik  4517

# %% [markdown]
# Now its time to get the number how many balls faced by each batsman

# %%
import pandas as pd

# Assuming df1 is your DataFrame containing the data
def show_ball(df, matchid, batsmanname):
    x = df[df['match_id'] == matchid][['batter', 'batsman_runs', 'over', 'ball']]
    x = x[x['batter'] == batsmanname]['ball'].count()
    return x

# List of match IDs
match_ids = df1['match_id'].unique() # Add more match IDs as needed

# Create an empty list to store tuples of batsman names and their runs
all_batsman_balls = []

# Iterate over each match ID
for match_id in match_ids:
    # Get unique batsman names for the current match ID
    unique_batsmen = df1[df1['match_id'] == match_id]['batter'].unique()
    
    # Iterate over unique batsmen for the current match
    for batsmanname in unique_batsmen:
        balls = show_ball(df1, match_id, batsmanname)
        all_batsman_balls.append((match_id, batsmanname, balls))

# Convert the list of tuples into a DataFrame
batsman_name_and_balls = pd.DataFrame(all_batsman_balls, columns=['match_id', 'batsman', 'balls_faced'])

print(batsman_name_and_balls)
# Out:
#        match_id          batsman  balls_faced
# 0        335982       SC Ganguly           12
# 1        335982      BB McCullum           77
# 2        335982       RT Ponting           20
# 3        335982        DJ Hussey           12
# 4        335982  Mohammad Hafeez            3
# ...         ...              ...          ...
# 15395   1370353           S Dube           21
# 15396   1370353        AM Rahane           14
# 15397   1370353        AT Rayudu            8
# 15398   1370353         MS Dhoni            1
# 15399   1370353        RA Jadeja            6
#
# [15400 rows x 3 columns]

# %%
batsman_name_and_balls.groupby(by='batsman')['balls_faced'].sum().reset_index().sort_values(by='balls_faced',ascending=False).head(10)
# Out:
#         batsman  balls_faced
# 597     V Kohli         5739
# 488    S Dhawan         5358
# 455   RG Sharma         4890
# 138   DA Warner         4719
# 519    SK Raina         4177
# 477  RV Uthappa         3927
# 357    MS Dhoni         3865
# 47    AM Rahane         3658
# 184   G Gambhir         3524
# 116    CH Gayle         3516

# %%
import pandas as pd

# Assuming batsman_name_and_runs and batsman_name_and_balls are your DataFrames

# Merge the two DataFrames on the 'batsman' column
X = pd.merge(batsman_name_and_balls.groupby(by='batsman')['balls_faced'].sum().reset_index().sort_values(by='balls_faced',ascending=False), batsman_name_and_runs.groupby(by='batsman')['runs'].sum().reset_index().sort_values(by='runs',ascending=False), on='batsman')

X['strike_rate'] = round((X['runs']/X['balls_faced']) * 100,2)

# %%
X
# Out:
#            batsman  balls_faced  runs  strike_rate
# 0          V Kohli       5739.0  7273       126.73
# 1         S Dhawan       5358.0  6617       123.50
# 2        RG Sharma       4890.0  6213       127.06
# 3        DA Warner       4719.0  6399       135.60
# 4         SK Raina       4177.0  5536       132.54
# ..             ...          ...   ...          ...
# 632   S Lamichhane          1.0     0         0.00
# 633     YA Abdulla          1.0     0         0.00
# 634        C Nanda          1.0     0         0.00
# 635         U Kaul          1.0     0         0.00
# 636  Y Prithvi Raj          1.0     0         0.00
#
# [637 rows x 4 columns]

# %%
df1['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field', 'retired out'], dtype=object)

# %%
df1[(df1['bowler'] == 'P Kumar') & 
    (df1['is_wicket'] == 1) & 
    (~df1['dismissal_kind'].isin(['retired hurt', 'hit wicket', 'obstructing the field', 'retired out']))]
# Out:
#         match_id  inning            batting_team                 bowling_team  \
# 807       335985       1          Mumbai Indians  Royal Challengers Bangalore
# 2504      335992       2        Rajasthan Royals  Royal Challengers Bangalore
# 3329      335996       1     Chennai Super Kings  Royal Challengers Bangalore
# 3362      335996       1     Chennai Super Kings  Royal Challengers Bangalore
# 5864      336006       2         Kings XI Punjab  Royal Challengers Bangalore
# ...          ...     ...                     ...                          ...
# 139432   1082603       1  Rising Pune Supergiant                Gujarat Lions
# 140291   1082606       2          Mumbai Indians                Gujarat Lions
# 141988   1082613       1   Kolkata Knight Riders                Gujarat Lions
# 148829   1082643       2     Sunrisers Hyderabad                Gujarat Lions
# 148834   1082643       2     Sunrisers Hyderabad                Gujarat Lions
#
# ...

# %%
batsman_name_and_balls
# Out:
#        match_id          batsman  runs  balls_faced
# 0        335982       SC Ganguly    10          NaN
# 1        335982      BB McCullum   158          NaN
# 2        335982       RT Ponting    20          NaN
# 3        335982        DJ Hussey    12          NaN
# 4        335982  Mohammad Hafeez     5          NaN
# ...         ...              ...   ...          ...
# 30795   1370353           S Dube    32         21.0
# 30796   1370353        AM Rahane    27         14.0
# 30797   1370353        AT Rayudu    19          8.0
# 30798   1370353         MS Dhoni     0          1.0
# 30799   1370353        RA Jadeja    15          6.0
#
# [30800 rows x 4 columns]

# %%
df2
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League       DJ Hussey
# ...       ...      ...         ...         ...          ...             ...
# 1019  1359544     2023   Bengaluru  2023-05-21       League    Shubman Gill
# 1020  1370350     2023     Chennai  2023-05-23  Qualifier 1      RD Gaikwad
# 1021  1370351     2023     Chennai  2023-05-24   Eliminator   Akash Madhwal
# 1022  1370352     2023   Ahmedabad  2023-05-26  Qualifier 2    Shubman Gill
# 1023  1370353     2023   Ahmedabad  2023-05-29        Final       DP Conway
#
# ...
